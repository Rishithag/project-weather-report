# %%
import os

# %%
os.chdir("C:/Users/Lenovo/Desktop/data")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
weather=pd.read_csv("weatherAUS.csv")
weather
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       01-12-2008   Albury     13.4     22.9       0.6          NaN
# 1       02-12-2008   Albury      7.4     25.1       0.0          NaN
# 2       03-12-2008   Albury     12.9     25.7       0.0          NaN
# 3       04-12-2008   Albury      9.2     28.0       0.0          NaN
# 4       05-12-2008   Albury     17.5     32.3       1.0          NaN
# 5       06-12-2008   Albury     14.6     29.7       0.2          NaN
# 6       07-12-2008   Albury     14.3     25.0       0.0          NaN
# 7       08-12-2008   Albury      7.7     26.7       0.0          NaN
# 8       09-12-2008   Albury      9.7     31.9       0.0          NaN
# 9       10-12-2008   Albury     13.1     30.1       1.4          NaN
# 10      11-12-2008   Albury     13.4     30.4       0.0          NaN
# 11      12-12-2008   Albury     15.9     21.7       2.2          NaN
# 12      13-12-2008   Albury     15.9     18.6      15.6          NaN
# ...

# %%
weather.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736267  0.104255     0.467261  0.072961
# MaxTemp        0.736267  1.000000 -0.074839     0.588915  0.469967
# Rainfall       0.104255 -0.074839  1.000000    -0.064549 -0.227525
# Evaporation    0.467261  0.588915 -0.064549     1.000000  0.366607
# Sunshine       0.072961  0.469967 -0.227525     0.366607  1.000000
# WindGustSpeed  0.177285  0.067690  0.133497     0.203001 -0.032831
# WindSpeed9am   0.176005  0.014680  0.086816     0.193936  0.008040
# WindSpeed3pm   0.175749  0.050800  0.057759     0.128895  0.056012
# Humidity9am   -0.234211 -0.505432  0.223725    -0.505890 -0.491603
# Humidity3pm    0.005999 -0.509270  0.255312    -0.392785 -0.629122
# Pressure9am   -0.451260 -0.332293 -0.168085    -0.269907  0.040959
# Pressure3pm   -0.461623 -0.427279 -0.126728    -0.293160 -0.020464
# Cloud9am       0.077625 -0.289865  0.198195    -0.185032 -0.675610
# ...

# %%
weather.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
weather1 = weather[pd.notnull(weather['RainToday'])]

# %%
weather1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date                 0
# Location             0
# MinTemp            468
# MaxTemp            307
# Rainfall             0
# Evaporation      59694
# Sunshine         66805
# WindGustDir       9163
# WindGustSpeed     9105
# WindDir9am        9660
# WindDir3pm        3670
# WindSpeed9am      1055
# WindSpeed3pm      2531
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Cloud9am         52625
# Cloud3pm         56094
# Temp9am            656
# Temp3pm           2624
# RainToday            0
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
meanMinTemp=weather1["MinTemp"].mean()
meanMinTemp
# Out:
# 12.184823865620327

# %%
weather1["MinTemp"].fillna(meanMinTemp,inplace=True)
# Out:
# D:\New folder (3)\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
meanMaxTemp=weather1["MaxTemp"].mean()
meanMaxTemp
# Out:
# 23.235120301822413

# %%
weather1["MaxTemp"].fillna(meanMaxTemp,inplace=True)

# %%
meanRainfall=weather1["Rainfall"].mean()
meanRainfall
# Out:
# 2.3499740743111954

# %%
weather1["Rainfall"].fillna(meanRainfall,inplace=True)

# %%
meanEvaporation=weather1["Evaporation"].mean()
meanEvaporation
# Out:
# 5.472515506887167

# %%
weather1["Evaporation"].fillna(meanEvaporation,inplace=True)

# %%
meanSunshine=weather1["Sunshine"].mean()
meanSunshine
# Out:
# 7.630539861047242

# %%
weather1["Sunshine"].fillna(meanSunshine,inplace=True)

# %%
weather1["WindGustDir"].value_counts()
# Out:
# W      9696
# SE     9241
# E      8985
# N      8941
# SSE    8905
# S      8859
# WSW    8802
# SW     8702
# SSW    8541
# WNW    7960
# NW     7939
# ENE    7924
# ESE    7244
# NE     7002
# NNW    6511
# NNE    6372
# Name: WindGustDir, dtype: int64

# %%
weather1["WindGustDir"].fillna("W",inplace=True)

# %%
meanWindGustSpeed=weather1["WindGustSpeed"].mean()
meanWindGustSpeed
# Out:
# 39.97051988882308

# %%
weather1["WindGustSpeed"].fillna(meanWindGustSpeed,inplace=True)

# %%
weather1["WindDir9am"].value_counts()
# Out:
# N      11266
# SE      9116
# E       8977
# SSE     8901
# NW      8471
# S       8424
# W       8207
# SW      8160
# NNE     7877
# NNW     7782
# ENE     7668
# ESE     7518
# NE      7477
# SSW     7397
# WNW     7100
# WSW     6786
# Name: WindDir9am, dtype: int64

# %%
weather1["WindDir9am"].fillna("N",inplace=True)

# %%
weather1["WindDir3pm"].value_counts()
# Out:
# SE     10578
# W       9810
# S       9488
# WSW     9231
# SW      9104
# SSE     9038
# N       8593
# WNW     8564
# NW      8394
# ESE     8311
# E       8272
# NE      8107
# SSW     7945
# NNW     7664
# ENE     7645
# NNE     6373
# Name: WindDir3pm, dtype: int64

# %%
weather1["WindDir3pm"].fillna("SE",inplace=True)

# %%
meanWindSpeed9am=weather1["WindSpeed9am"].mean()
meanWindSpeed9am
# Out:
# 13.990496092519967

# %%
weather1["WindSpeed9am"].fillna(meanWindSpeed9am,inplace=True)

# %%
meanWindSpeed3pm=weather1["WindSpeed3pm"].mean()
meanWindSpeed3pm
# Out:
# 18.631140782316862

# %%
weather1["WindSpeed3pm"].fillna(meanWindSpeed3pm,inplace=True)

# %%
weather1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Cloud9am         52625
# Cloud3pm         56094
# Temp9am            656
# Temp3pm           2624
# RainToday            0
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
weather1['RainToday']=labelencoder.fit_transform(weather1['RainToday'])
weather1['RainTomorrow']=labelencoder.fit_transform(weather1['RainTomorrow'])
weather1
# Out:
# D:\New folder (3)\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\New folder (3)\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       01-12-2008   Albury     13.4     22.9       0.6     5.472516
# ...

# %%
weather1.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.734443  0.103759     0.354792  0.052123
# MaxTemp        0.734443  1.000000 -0.074601     0.444030  0.332758
# Rainfall       0.103759 -0.074601  1.000000    -0.038223 -0.173466
# Evaporation    0.354792  0.444030 -0.038223     1.000000  0.290782
# Sunshine       0.052123  0.332758 -0.173466     0.290782  1.000000
# WindGustSpeed  0.174089  0.067158  0.127944     0.148147 -0.022076
# WindSpeed9am   0.174932  0.014405  0.086387     0.141341  0.006504
# WindSpeed3pm   0.174369  0.050782  0.057063     0.094617  0.039886
# Humidity9am   -0.234264 -0.505766  0.223725    -0.381685 -0.354335
# Humidity3pm    0.005683 -0.509680  0.255312    -0.295021 -0.450320
# Pressure9am   -0.451160 -0.331674 -0.168085    -0.212738  0.031106
# Pressure3pm   -0.461807 -0.426862 -0.126728    -0.232373 -0.015384
# Cloud9am       0.077252 -0.289875  0.198195    -0.165593 -0.571880
# ...

# %%
weather1.boxplot(column="WindGustSpeed",by="RainToday")

# %%
raintoday=weather1['RainToday']
WindGustSpeed=weather1['WindGustSpeed']

# %%
plt.plot(raintoday,WindGustSpeed,'o')
plt.ylabel("WindGustSpeed")
plt.xlabel("RainToday")
#From this we can infer that there is an equal chance of having rain and not having rains today.
#so we can not estimate rain based on  the wind gust speed only.
# Out:
# Text(0.5, 0, 'RainToday')

# %%
raintoday=weather1['RainToday']
windspeed9=weather1['WindSpeed9am']

# %%
plt.plot(raintoday,windspeed9,'o')
plt.ylabel("WindSpeed9am")
plt.xlabel("RainToday")
#From this we can infer that till  65 there is equal chance of having and not having rains 
# From 80 we can come to a conclusion of having or not having rains.. If the wind speed is 81 also
# we will not have rains which means that wind speed is not sufficient...
# hence if the wind speed is between 90-120 we have max probability of having rains... 
#  Also if the wind speed is  too high also we may not have rains
# Out:
# Text(0.5, 0, 'RainToday')

# %%
X=weather1['WindSpeed9am']
Y=weather1['RainToday']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=1)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
from sklearn.linear_model.logistic import LogisticRegression
lqsr=LogisticRegression(random_state=0)
lqsr.fit(X_train,Y_train)
# Out:
# D:\New folder (3)\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
X_test=X_test.values.reshape(-1,1)

# %%
y_pred=lqsr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc_sco=accuracy_score(Y_test,y_pred)
acc_sco
# Out:
# 0.7771641658527924

# %%
X=weather1['WindSpeed3pm']#x denotes input
Y=weather1['RainToday']#y denotes output

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=1)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
from sklearn.linear_model.logistic import LogisticRegression
lqsr=LogisticRegression(random_state=0)
lqsr.fit(X_train,Y_train)
# Out:
# D:\New folder (3)\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
X_test=X_test.values.reshape(-1,1)

# %%
y_pred=lqsr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc_sco=accuracy_score(Y_test,y_pred)
acc_sco
# Out:
# 0.7770043505282784

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_y_test=dtc_clf.predict(X_test)
dtc_y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(Y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[43746,    12],
#        [12553,     4]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_accu_test=accuracy_score(Y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.7768800497203232

# %%
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rf_classi=RandomForestClassifier()
rf_classi.fit(X_train,Y_train)
# Out:
# D:\New folder (3)\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_classi_y_test=dtc_clf.predict(X_test)
rf_classi_y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(Y_test,rf_classi_y_test)
rf_cm_test
# Out:
# array([[43746,    12],
#        [12553,     4]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_accu_test=accuracy_score(Y_test,rf_classi_y_test)
rf_accu_test
# Out:
# 0.7768800497203232
